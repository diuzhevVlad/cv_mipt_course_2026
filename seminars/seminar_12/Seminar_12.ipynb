# %% [markdown]
# # Deep learning for computer vision
#
#
# This notebook will teach you to build and train convolutional networks for image recognition. Brace yourselves. Thanks [Yandex Data School Analysis](https://github.com/yandexdataschool/Practical_DL/blob/fall21/week03_convnets/seminar_pytorch.ipynb) for this work!

# %% [markdown]
# # CIFAR dataset
# This week, we shall focus on the image recognition problem on cifar10 dataset
# * 60k images of shape 3x32x32
# * 10 different classes: planes, dogs, cats, trucks, etc.
#
# ![image](https://github.com/yandexdataschool/Practical_DL/raw/fall21/week03_convnets/cifar10.jpg)

# %%
# when running in colab, un-comment this
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall19/week03_convnets/cifar.py
# Out:
# --2026-04-13 16:37:31--  https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall19/week03_convnets/cifar.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2396 (2.3K) [text/plain]
# Saving to: ‘cifar.py’
#
# cifar.py            100%[===================>]   2.34K  --.-KB/s    in 0s
#
# 2026-04-13 16:37:49 (48.4 MB/s) - ‘cifar.py’ saved [2396/2396]

# %%
import numpy as np
from cifar import load_cifar10
X_train, y_train, X_val, y_val, X_test, y_test = load_cifar10("cifar_data")

class_names = np.array(['airplane', 'automobile', 'bird', 'cat', 'deer',
                        'dog', 'frog', 'horse', 'ship', 'truck'])

print(X_train.shape,y_train.shape)
# Out:
# Dataset not found. Downloading...
# (40000, 3, 32, 32) (40000,)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=[12,10])
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.xlabel(class_names[y_train[i]])
    plt.imshow(np.transpose(X_train[i],[1,2,0]))

# %% [markdown]
# # Building a network
#
# Simple neural networks with layers applied on top of one another can be implemented as `torch.nn.Sequential` - just add a list of pre-built modules and let it train.

# %%
import torch, torch.nn as nn
import torch.nn.functional as F

# a special module that converts [batch, channel, w, h] to [batch, units]
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

# %% [markdown]
# Let's start with a dense network for our baseline:

# %%
model = nn.Sequential()

# reshape from "images" to flat vectors
model.add_module('flatten', Flatten())

# dense "head"
model.add_module('dense1', nn.Linear(3 * 32 * 32, 64))
model.add_module('dense1_relu', nn.ReLU())
model.add_module('dense2_logits', nn.Linear(64, 10)) # logits for 10 classes

# %% [markdown]
# As in our basic tutorial, we train our model with negative log-likelihood aka crossentropy.

# %%
def compute_loss(X_batch, y_batch):
    X_batch = torch.as_tensor(X_batch, dtype=torch.float32)
    y_batch = torch.as_tensor(y_batch, dtype=torch.int64)
    logits = model(X_batch)
    return F.cross_entropy(logits, y_batch).mean()

# %%
# example
compute_loss(X_train[:5], y_train[:5])
# Out:
# tensor(2.2680, grad_fn=<MeanBackward0>)

# %% [markdown]
# ### Training on minibatches
# * We got 40k images, that's way too many for a full-batch SGD. Let's train on minibatches instead
# * Below is a function that splits the training sample into minibatches

# %%
# An auxilary function that returns mini-batches for neural network training
def iterate_minibatches(X, y, batchsize):
    indices = np.random.permutation(np.arange(len(X)))
    for start in range(0, len(indices), batchsize):
        ix = indices[start: start + batchsize]
        yield X[ix], y[ix]

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.numpy())
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32))
        y_pred = logits.max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 100 took 0.591s
#   training loss (in-iteration): 	1.554294
#   validation accuracy: 			44.72 %
# Epoch 2 of 100 took 0.558s
#   training loss (in-iteration): 	1.538658
#   validation accuracy: 			45.43 %
# Epoch 3 of 100 took 0.586s
#   training loss (in-iteration): 	1.524675
#   validation accuracy: 			46.10 %
# Epoch 4 of 100 took 0.533s
#   training loss (in-iteration): 	1.510376
#   validation accuracy: 			46.51 %
# Epoch 5 of 100 took 0.544s
#   training loss (in-iteration): 	1.497293
#   validation accuracy: 			46.53 %
# Epoch 6 of 100 took 0.534s
#   training loss (in-iteration): 	1.486046
#   validation accuracy: 			47.66 %
# Epoch 7 of 100 took 0.536s
#   training loss (in-iteration): 	1.475158
#   validation accuracy: 			47.38 %
# Epoch 8 of 100 took 0.547s
#   training loss (in-iteration): 	1.466069
#   validation accuracy: 			47.72 %
# Epoch 9 of 100 took 0.564s
#   training loss (in-iteration): 	1.456668
#   validation accuracy: 			46.97 %
# Epoch 10 of 100 took 0.516s
#   training loss (in-iteration): 	1.443941
#   validation accuracy: 			48.01 %
# Epoch 11 of 100 took 0.555s
#   training loss (in-iteration): 	1.435050
#   validation accuracy: 			48.38 %
# Epoch 12 of 100 took 0.539s
#   training loss (in-iteration): 	1.428043
#   validation accuracy: 			48.32 %
# Epoch 13 of 100 took 0.568s
#   training loss (in-iteration): 	1.420105
#   validation accuracy: 			48.10 %
# Epoch 14 of 100 took 0.545s
#   training loss (in-iteration): 	1.409331
#   validation accuracy: 			48.60 %
# Epoch 15 of 100 took 0.739s
#   training loss (in-iteration): 	1.402321
#   validation accuracy: 			48.70 %
# Epoch 16 of 100 took 0.610s
#   training loss (in-iteration): 	1.395896
#   validation accuracy: 			49.21 %
# Epoch 17 of 100 took 0.544s
#   training loss (in-iteration): 	1.388405
#   validation accuracy: 			49.27 %
# Epoch 18 of 100 took 0.581s
#   training loss (in-iteration): 	1.380869
#   validation accuracy: 			48.51 %
# Epoch 19 of 100 took 0.550s
#   training loss (in-iteration): 	1.373629
#   validation accuracy: 			49.64 %
# Epoch 20 of 100 took 0.598s
#   training loss (in-iteration): 	1.366124
#   validation accuracy: 			49.45 %
# Epoch 21 of 100 took 0.588s
#   training loss (in-iteration): 	1.360146
#   validation accuracy: 			48.70 %
# Epoch 22 of 100 took 0.531s
#   training loss (in-iteration): 	1.356946
#   validation accuracy: 			49.31 %
# Epoch 23 of 100 took 0.520s
#   training loss (in-iteration): 	1.351178
#   validation accuracy: 			50.00 %
# Epoch 24 of 100 took 0.524s
#   training loss (in-iteration): 	1.342195
#   validation accuracy: 			49.67 %
# Epoch 25 of 100 took 0.565s
#   training loss (in-iteration): 	1.335295
#   validation accuracy: 			47.81 %
# Epoch 26 of 100 took 0.589s
#   training loss (in-iteration): 	1.330305
#   validation accuracy: 			48.95 %
# Epoch 27 of 100 took 0.580s
#   training loss (in-iteration): 	1.322905
#   validation accuracy: 			49.57 %
# Epoch 28 of 100 took 0.560s
#   training loss (in-iteration): 	1.318148
#   validation accuracy: 			49.75 %
# Epoch 29 of 100 took 0.606s
#   training loss (in-iteration): 	1.313449
#   validation accuracy: 			49.82 %
# Epoch 30 of 100 took 0.587s
#   training loss (in-iteration): 	1.311762
#   validation accuracy: 			49.91 %
# Epoch 31 of 100 took 0.531s
#   training loss (in-iteration): 	1.302623
#   validation accuracy: 			50.65 %
# Epoch 32 of 100 took 0.580s
#   training loss (in-iteration): 	1.301363
#   validation accuracy: 			49.93 %
# Epoch 33 of 100 took 0.545s
#   training loss (in-iteration): 	1.293719
#   validation accuracy: 			49.69 %
# Epoch 34 of 100 took 0.559s
#   training loss (in-iteration): 	1.287419
#   validation accuracy: 			50.30 %
# Epoch 35 of 100 took 0.529s
#   training loss (in-iteration): 	1.283685
#   validation accuracy: 			49.68 %
# Epoch 36 of 100 took 0.556s
#   training loss (in-iteration): 	1.279375
#   validation accuracy: 			49.99 %
# Epoch 37 of 100 took 0.552s
#   training loss (in-iteration): 	1.273442
#   validation accuracy: 			51.09 %
# Epoch 38 of 100 took 0.563s
#   training loss (in-iteration): 	1.269599
#   validation accuracy: 			50.12 %
# Epoch 39 of 100 took 0.584s
#   training loss (in-iteration): 	1.267231
#   validation accuracy: 			49.40 %
# Epoch 40 of 100 took 0.548s
#   training loss (in-iteration): 	1.260073
#   validation accuracy: 			50.66 %
# Epoch 41 of 100 took 0.600s
#   training loss (in-iteration): 	1.257947
#   validation accuracy: 			49.05 %
# Epoch 42 of 100 took 0.584s
#   training loss (in-iteration): 	1.252015
#   validation accuracy: 			50.85 %
# Epoch 43 of 100 took 0.536s
#   training loss (in-iteration): 	1.247469
#   validation accuracy: 			50.45 %
# Epoch 44 of 100 took 0.539s
#   training loss (in-iteration): 	1.243687
#   validation accuracy: 			50.82 %
# Epoch 45 of 100 took 0.624s
#   training loss (in-iteration): 	1.238012
#   validation accuracy: 			51.01 %
# Epoch 46 of 100 took 0.637s
#   training loss (in-iteration): 	1.233041
#   validation accuracy: 			51.18 %
# Epoch 47 of 100 took 0.596s
#   training loss (in-iteration): 	1.231604
#   validation accuracy: 			50.80 %
# Epoch 48 of 100 took 0.590s
#   training loss (in-iteration): 	1.227333
#   validation accuracy: 			50.45 %
# Epoch 49 of 100 took 0.571s
#   training loss (in-iteration): 	1.223868
#   validation accuracy: 			50.81 %
# Epoch 50 of 100 took 0.596s
#   training loss (in-iteration): 	1.221969
#   validation accuracy: 			50.73 %
# Epoch 51 of 100 took 0.526s
#   training loss (in-iteration): 	1.219224
#   validation accuracy: 			50.05 %
# Epoch 52 of 100 took 0.573s
#   training loss (in-iteration): 	1.217922
#   validation accuracy: 			50.81 %
# Epoch 53 of 100 took 0.536s
#   training loss (in-iteration): 	1.210095
#   validation accuracy: 			49.83 %
# Epoch 54 of 100 took 0.527s
#   training loss (in-iteration): 	1.208510
#   validation accuracy: 			47.92 %
# Epoch 55 of 100 took 0.533s
#   training loss (in-iteration): 	1.200743
#   validation accuracy: 			49.40 %
# Epoch 56 of 100 took 0.532s
#   training loss (in-iteration): 	1.198956
#   validation accuracy: 			50.84 %
# Epoch 57 of 100 took 0.535s
#   training loss (in-iteration): 	1.198568
#   validation accuracy: 			50.12 %
# Epoch 58 of 100 took 0.523s
#   training loss (in-iteration): 	1.192212
#   validation accuracy: 			50.81 %
# Epoch 59 of 100 took 0.533s
#   training loss (in-iteration): 	1.187816
#   validation accuracy: 			48.12 %
# Epoch 60 of 100 took 0.658s
#   training loss (in-iteration): 	1.185131
#   validation accuracy: 			50.74 %
# Epoch 61 of 100 took 0.575s
#   training loss (in-iteration): 	1.185792
#   validation accuracy: 			48.99 %
# Epoch 62 of 100 took 0.521s
#   training loss (in-iteration): 	1.176018
#   validation accuracy: 			50.64 %
# Epoch 63 of 100 took 0.544s
#   training loss (in-iteration): 	1.177000
#   validation accuracy: 			48.72 %
# Epoch 64 of 100 took 0.567s
#   training loss (in-iteration): 	1.173135
#   validation accuracy: 			49.70 %
# Epoch 65 of 100 took 0.559s
#   training loss (in-iteration): 	1.173092
#   validation accuracy: 			49.34 %
# Epoch 66 of 100 took 0.534s
#   training loss (in-iteration): 	1.168136
#   validation accuracy: 			50.90 %
# Epoch 67 of 100 took 0.550s
#   training loss (in-iteration): 	1.163900
#   validation accuracy: 			51.04 %
# Epoch 68 of 100 took 0.537s
#   training loss (in-iteration): 	1.159633
#   validation accuracy: 			50.32 %
# Epoch 69 of 100 took 0.527s
#   training loss (in-iteration): 	1.157990
#   validation accuracy: 			51.42 %
# Epoch 70 of 100 took 0.542s
#   training loss (in-iteration): 	1.157217
#   validation accuracy: 			50.23 %
# Epoch 71 of 100 took 0.550s
#   training loss (in-iteration): 	1.150592
#   validation accuracy: 			50.93 %
# Epoch 72 of 100 took 0.520s
#   training loss (in-iteration): 	1.148280
#   validation accuracy: 			50.41 %
# Epoch 73 of 100 took 0.571s
#   training loss (in-iteration): 	1.144736
#   validation accuracy: 			49.23 %
# Epoch 74 of 100 took 0.552s
#   training loss (in-iteration): 	1.145032
#   validation accuracy: 			51.50 %
# Epoch 75 of 100 took 0.560s
#   training loss (in-iteration): 	1.144733
#   validation accuracy: 			49.46 %
# Epoch 76 of 100 took 0.527s
#   training loss (in-iteration): 	1.141714
#   validation accuracy: 			50.26 %
# Epoch 77 of 100 took 0.522s
#   training loss (in-iteration): 	1.140194
#   validation accuracy: 			49.60 %
# Epoch 78 of 100 took 0.528s
#   training loss (in-iteration): 	1.134220
#   validation accuracy: 			50.55 %
# Epoch 79 of 100 took 0.535s
#   training loss (in-iteration): 	1.129169
#   validation accuracy: 			51.17 %
# Epoch 80 of 100 took 0.619s
#   training loss (in-iteration): 	1.127842
#   validation accuracy: 			49.87 %
# Epoch 81 of 100 took 0.568s
#   training loss (in-iteration): 	1.125316
#   validation accuracy: 			50.65 %
# Epoch 82 of 100 took 0.529s
#   training loss (in-iteration): 	1.125276
#   validation accuracy: 			50.68 %
# Epoch 83 of 100 took 0.544s
#   training loss (in-iteration): 	1.118547
#   validation accuracy: 			51.57 %
# Epoch 84 of 100 took 0.520s
#   training loss (in-iteration): 	1.118418
#   validation accuracy: 			49.67 %
# Epoch 85 of 100 took 0.531s
#   training loss (in-iteration): 	1.118504
#   validation accuracy: 			50.39 %
# Epoch 86 of 100 took 0.556s
#   training loss (in-iteration): 	1.113560
#   validation accuracy: 			50.68 %
# Epoch 87 of 100 took 0.528s
#   training loss (in-iteration): 	1.111427
#   validation accuracy: 			51.07 %
# Epoch 88 of 100 took 0.544s
#   training loss (in-iteration): 	1.108951
#   validation accuracy: 			50.58 %
# Epoch 89 of 100 took 0.565s
#   training loss (in-iteration): 	1.105440
#   validation accuracy: 			51.32 %
# Epoch 90 of 100 took 0.554s
#   training loss (in-iteration): 	1.105071
#   validation accuracy: 			50.84 %
# Epoch 91 of 100 took 0.557s
#   training loss (in-iteration): 	1.102733
#   validation accuracy: 			51.25 %
# Epoch 92 of 100 took 0.567s
#   training loss (in-iteration): 	1.100241
#   validation accuracy: 			48.76 %
# Epoch 93 of 100 took 0.612s
#   training loss (in-iteration): 	1.095316
#   validation accuracy: 			50.44 %
# Epoch 94 of 100 took 0.557s
#   training loss (in-iteration): 	1.089488
#   validation accuracy: 			50.94 %
# Epoch 95 of 100 took 0.561s
#   training loss (in-iteration): 	1.089185
#   validation accuracy: 			49.86 %
# Epoch 96 of 100 took 0.532s
#   training loss (in-iteration): 	1.090589
#   validation accuracy: 			50.81 %
# Epoch 97 of 100 took 0.535s
#   training loss (in-iteration): 	1.085516
#   validation accuracy: 			50.17 %
# Epoch 98 of 100 took 0.514s
#   training loss (in-iteration): 	1.084457
#   validation accuracy: 			50.49 %
# Epoch 99 of 100 took 0.551s
#   training loss (in-iteration): 	1.082300
#   validation accuracy: 			51.70 %
# Epoch 100 of 100 took 0.535s
#   training loss (in-iteration): 	1.077885
#   validation accuracy: 			50.88 %

# %% [markdown]
# Don't wait for full 100 epochs. You can interrupt training after 5-20 epochs once validation accuracy stops going up.
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ### Final test

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32))
    y_pred = logits.max(1)[1].data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)
    
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		50.31 %
# Achievement unlocked: 60lvl Warlock!

# %% [markdown]
# ## Task I: small convolution net
# ### First step
#
# Let's create a mini-convolutional network with roughly such architecture:
# * Input layer
# * 3x3 convolution with 10 filters and _ReLU_ activation
# * 2x2 pooling (or set previous convolution stride to 3)
# * Flatten
# * Dense layer with 100 neurons and _ReLU_ activation
# * 10% dropout
# * Output dense layer.
#
#
# __Convolutional layers__ in torch are just like all other layers, but with a specific set of parameters:
#
# __`...`__
#
# __`model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3)) # convolution`__
#
# __`model.add_module('pool1', nn.MaxPool2d(2)) # max pooling 2x2`__
#
# __`...`__
#
#
# Once you're done (and compute_loss no longer raises errors), train it with __Adam__ optimizer with default params (feel free to modify the code above).
#
# If everything is right, you should get at least __50%__ validation accuracy.

# %%
model = nn.Sequential(
    nn.Conv2d(3, 10, kernel_size=3),
    nn.ReLU(),
    nn.MaxPool2d(2),
    Flatten(),
    nn.Linear(10 * 15 * 15, 100),
    nn.ReLU(),
    nn.Dropout(0.1),
    nn.Linear(100, 10),
)

opt = torch.optim.Adam(model.parameters())
train_loss = []
val_accuracy = []
compute_loss(X_train[:5], y_train[:5])
# Out:
# tensor(2.3949, grad_fn=<MeanBackward0>)

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# __Hint:__ If you don't want to compute shapes by hand, just plug in any shape (e.g. 1 unit) and run compute_loss. You will see something like this:
#
# __`RuntimeError: size mismatch, m1: [5 x 1960], m2: [1 x 64] at /some/long/path/to/torch/operation`__
#
# See the __1960__ there? That's your actual input shape.
#
# ## Task 2: adding normalization
#
# * Add batch norm (with default params) between convolution and ReLU
#   * nn.BatchNorm*d (1d for dense, 2d for conv)
#   * usually better to put them after linear/conv but before nonlinearity
# * Re-train the network with the same optimizer, it should get at least 60% validation accuracy at peak.

# %%
model = nn.Sequential(
    nn.Conv2d(3, 10, kernel_size=3),
    nn.BatchNorm2d(10),
    nn.ReLU(),
    nn.MaxPool2d(2),
    Flatten(),
    nn.Linear(10 * 15 * 15, 100),
    nn.BatchNorm1d(100),
    nn.ReLU(),
    nn.Dropout(0.1),
    nn.Linear(100, 10),
)

opt = torch.optim.Adam(model.parameters())
train_loss = []
val_accuracy = []
compute_loss(X_train[:5], y_train[:5])
# Out:
# tensor(2.4053, grad_fn=<MeanBackward0>)

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
# ## Task 3: Data Augmentation
#
# There's a powerful torch tool for image preprocessing useful to do data preprocessing and augmentation.
#
# Here's how it works: we define a pipeline that
# * makes random crops of data (augmentation)
# * randomly flips image horizontally (augmentation)
# * then normalizes it (preprocessing)

# %%
from torchvision import transforms
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2023, 0.1994, 0.2010))

transform_augment = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation([-30, 30]),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

# %%
from torchvision.datasets import CIFAR10
train_loader = CIFAR10("./cifar_data/", train=True, transform=transform_augment)

train_batch_gen = torch.utils.data.DataLoader(train_loader, 
                                              batch_size=32,
                                              shuffle=True,
                                              num_workers=1)

# %%
plt.figure(figsize=(10, 5))
for (x_batch, y_batch) in train_batch_gen:
    print('X:', type(x_batch), x_batch.shape)
    print('y:', type(y_batch), y_batch.shape)

    for i, img in enumerate(x_batch.numpy()[:8]):
        plt.subplot(2, 4, i + 1)
        plt.imshow(np.clip(img.transpose([1, 2, 0]) * stds + means, 0, 1))
        plt.axis('off')
    break
# Out:
# X: <class 'torch.Tensor'> torch.Size([32, 3, 32, 32])
# y: <class 'torch.Tensor'> torch.Size([32])

# %% [markdown]
# When testing, we don't need random crops, just normalize with same statistics.

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

test_loader = CIFAR10('./cifar_data/', train=False, transform=transform_test)

test_batch_gen = torch.utils.data.DataLoader(
    test_loader,
    batch_size=32,
    shuffle=False,
    num_workers=1,
)

# %% [markdown]
# # Homework 2.2: The Quest For A Better Network
#
# In this assignment you will build a monster network to solve CIFAR10 image classification.
#
# This notebook is intended as a sequel to seminar 3, please give it a try if you haven't done so yet.

# %% [markdown]
# (please read it at least diagonally)
#
# * The ultimate quest is to create a network that has as high __accuracy__ as you can push it.
# * There is a __mini-report__ at the end that you will have to fill in. We recommend reading it first and filling it while you iterate.
#
# ## Grading
# * starting at zero points
# * +20% for describing your iteration path in a report below.
# * +20% for building a network that gets above 20% accuracy
# * +10% for beating each of these milestones on __TEST__ dataset:
#     * 50% (50% points)
#     * 60% (60% points)
#     * 65% (70% points)
#     * 70% (80% points)
#     * 75% (90% points)
#     * 80% (full points)
#
# ## Restrictions
# * Please do NOT use pre-trained networks for this assignment until you reach 80%.
#  * In other words, base milestones must be beaten without pre-trained nets (and such net must be present in the e-mail). After that, you can use whatever you want.
# * you __can__ use validation data for training, but you __can't'__ do anything with test data apart from running the evaluation procedure.
#
# ## Tips on what can be done:
#
#
#  * __Network size__
#    * MOAR neurons,
#    * MOAR layers, ([torch.nn docs](http://pytorch.org/docs/master/nn.html))
#
#    * Nonlinearities in the hidden layers
#      * tanh, relu, leaky relu, etc
#    * Larger networks may take more epochs to train, so don't discard your net just because it could didn't beat the baseline in 5 epochs.
#
#    * Ph'nglui mglw'nafh Cthulhu R'lyeh wgah'nagl fhtagn!
#
#
# ### The main rule of prototyping: one change at a time
#    * By now you probably have several ideas on what to change. By all means, try them out! But there's a catch: __never test several new things at once__.
#
#
# ### Optimization
#    * Training for 100 epochs regardless of anything is probably a bad idea.
#    * Some networks converge over 5 epochs, others - over 500.
#    * Way to go: stop when validation score is 10 iterations past maximum
#    * You should certainly use adaptive optimizers
#      * rmsprop, nesterov_momentum, adam, adagrad and so on.
#      * Converge faster and sometimes reach better optima
#      * It might make sense to tweak learning rate/momentum, other learning parameters, batch size and number of epochs
#    * __BatchNormalization__ (nn.BatchNorm2d) for the win!
#      * Sometimes more batch normalization is better.
#    * __Regularize__ to prevent overfitting
#      * Add some L2 weight norm to the loss function, PyTorch will do the rest
#        * Can be done manually or with weight_decay parameter of a optimizer ([for example SGD's doc](https://pytorch.org/docs/stable/optim.html#torch.optim.SGD)).
#      * Dropout (`nn.Dropout`) - to prevent overfitting
#        * Don't overdo it. Check if it actually makes your network better
#
# ### Convolution architectures
#    * This task __can__ be solved by a sequence of convolutions and poolings with batch_norm and ReLU seasoning, but you shouldn't necessarily stop there.
#    * [Inception family](https://hacktilldawn.com/2016/09/25/inception-modules-explained-and-implemented/), [ResNet family](https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035?gi=9018057983ca), [Densely-connected convolutions (exotic)](https://arxiv.org/abs/1608.06993), [Capsule networks (exotic)](https://arxiv.org/abs/1710.09829)
#    * Please do try a few simple architectures before you go for resnet-152.
#    * Warning! Training convolutional networks can take long without GPU. That's okay.
#      * If you are CPU-only, we still recomment that you try a simple convolutional architecture
#      * a perfect option is if you can set it up to run at nighttime and check it up at the morning.
#      * Make reasonable layer size estimates. A 128-neuron first convolution is likely an overkill.
#      * __To reduce computation__ time by a factor in exchange for some accuracy drop, try using __stride__ parameter. A stride=2 convolution should take roughly 1/4 of the default (stride=1) one.
#
#
# ### Data augmemntation
#    * getting 5x as large dataset for free is a great
#      * Zoom-in+slice = move
#      * Rotate+zoom(to remove black stripes)
#      * Add Noize (gaussian or bernoulli)
#    * Simple way to do that (if you have PIL/Image):
#      * ```from scipy.misc import imrotate,imresize```
#      * and a few slicing
#      * Other cool libraries: cv2, skimake, PIL/Pillow
#    * A more advanced way is to use torchvision transforms:
#     ```
#     transform_train = transforms.Compose([
#         transforms.RandomCrop(32, padding=4),
#         transforms.RandomHorizontalFlip(),
#         transforms.ToTensor(),
#         transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
#     ])
#     trainset = torchvision.datasets.CIFAR10(root=path_to_cifar_like_in_seminar, train=True, download=True, transform=transform_train)
#     trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)
#
#     ```
#    * Or use this tool from Keras (requires theano/tensorflow): [tutorial](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), [docs](https://keras.io/preprocessing/image/)
#    * Stay realistic. There's usually no point in flipping dogs upside down as that is not the way you usually see them.
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class SimpleCIFARDataset(torch.utils.data.Dataset):
    def __init__(self, X, y, transform=None):
        self.X = X
        self.y = y
        self.transform = transform

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        img = self.X[idx].transpose(1, 2, 0)
        img = np.clip(img, 0, 1).astype(np.float32)
        if self.transform is not None:
            img = self.transform(img)
        else:
            img = torch.tensor(self.X[idx], dtype=torch.float32)
        return img, int(self.y[idx])

train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

val_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

train_ds = SimpleCIFARDataset(X_train, y_train, train_transform)
val_ds = SimpleCIFARDataset(X_val, y_val, val_transform)
test_ds = SimpleCIFARDataset(X_test, y_test, val_transform)

train_dl = torch.utils.data.DataLoader(train_ds, batch_size=128, shuffle=True, num_workers=1)
val_dl = torch.utils.data.DataLoader(val_ds, batch_size=256, shuffle=False, num_workers=1)
test_dl = torch.utils.data.DataLoader(test_ds, batch_size=256, shuffle=False, num_workers=1)

model = nn.Sequential(
    nn.Conv2d(3, 32, kernel_size=3, padding=1),
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Conv2d(32, 64, kernel_size=3, padding=1),
    nn.BatchNorm2d(64),
    nn.ReLU(),
    nn.MaxPool2d(2),

    nn.Conv2d(64, 128, kernel_size=3, padding=1),
    nn.BatchNorm2d(128),
    nn.ReLU(),
    nn.MaxPool2d(2),

    Flatten(),
    nn.Linear(128 * 4 * 4, 256),
    nn.ReLU(),
    nn.Dropout(0.3),
    nn.Linear(256, 10),
).to(device)

opt = torch.optim.Adam(model.parameters(), lr=1e-3)


def evaluate(dataloader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            logits = model(x_batch)
            pred = logits.argmax(dim=1)
            correct += (pred == y_batch).sum().item()
            total += y_batch.size(0)
    return correct / total

num_epochs = 10
best_val = 0.0
for epoch in range(num_epochs):
    model.train()
    for x_batch, y_batch in train_dl:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        opt.zero_grad()
        loss = F.cross_entropy(model(x_batch), y_batch)
        loss.backward()
        opt.step()

    val_acc = evaluate(val_dl)
    best_val = max(best_val, val_acc)
    print(f'epoch {epoch + 1}: val_acc = {val_acc:.4f}')

print('best val_acc =', best_val)
print('test_acc =', evaluate(test_dl))
# Out:
# epoch 1: val_acc = 0.5556
# epoch 2: val_acc = 0.6172
# epoch 3: val_acc = 0.6490
# epoch 4: val_acc = 0.6962
# epoch 5: val_acc = 0.7061
# epoch 6: val_acc = 0.7252
# epoch 7: val_acc = 0.7301
# epoch 8: val_acc = 0.7357
# epoch 9: val_acc = 0.7371
# epoch 10: val_acc = 0.7472
# best val_acc = 0.7472
# test_acc = 0.747
